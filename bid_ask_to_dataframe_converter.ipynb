# %%
# %run useful_functions.py
# Out:
# C:\Users\natha\Desktop\17-Cyber-risk_and_the_cross-section_of_stock_returns-main\17-Cyber-risk_and_the_cross-section_of_stock_returns-main\Work_Nathan\useful_functions.py:943: SyntaxWarning: invalid escape sequence '\s'
#   item1A = re.sub('\s{2,}',' ', item1A)
# C:\Users\natha\Desktop\17-Cyber-risk_and_the_cross-section_of_stock_returns-main\17-Cyber-risk_and_the_cross-section_of_stock_returns-main\Work_Nathan\useful_functions.py:954: SyntaxWarning: invalid escape sequence '\s'
#   document = re.sub('\s{2,}',' ', document)
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\natha\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# update 18

# %%
file_path = 'Financial_values/AAPL/bid_ask_monthly.csv'
price_table = pd.read_csv(file_path)

price_table['date'] = price_table['date'].apply(lambda x: x[:-3])

price_table.set_index('date', inplace=True)

# %%
series_list=[]
for ticker in tqdm(os.listdir('Financial_values/')):
    try:
        directory='Financial_values/'+ticker+'/bid_ask_monthly.csv'
        price_table = pd.read_csv(directory)
        
        price_table['date'] = price_table['date'].apply(lambda x: x[:-3])
        price_table.set_index('date', inplace=True)
    
        price_table[ticker]=(price_table['plus_cost_last']+price_table['minus_cost_last'])*0.5
    
        prc_table=price_table[[ticker]]


    except FileNotFoundError:

        prc_table=pd.Series(name=ticker, index=pd.Index([], name='date'))
    
    series_list.append(prc_table)
# Out:
#   0%|          | 0/7083 [00:00<?, ?it/s]

# %%
bid_ask_table=pd.concat(series_list, axis=1)
bid_ask_table.sort_index(inplace=True)

# %%
display(bid_ask_table)
save_path_ratio='Financial_ratios/'
bid_ask_table.to_csv(save_path_ratio + 'bid_ask_table.csv.gz')
# Out:
#                 A        AA      AAAU       AAC  AACC      AACI      AADI  \
# date
# 1925-12       NaN       NaN       NaN       NaN   NaN       NaN       NaN
# 1926-01       NaN       NaN       NaN       NaN   NaN       NaN       NaN
# 1926-02       NaN       NaN       NaN       NaN   NaN       NaN       NaN
# 1926-03       NaN       NaN       NaN       NaN   NaN       NaN       NaN
# 1926-04       NaN       NaN       NaN       NaN   NaN       NaN       NaN
# ...           ...       ...       ...       ...   ...       ...       ...
# 2023-08  0.000105  0.000098  0.000020  0.000002   NaN  0.000005  0.000250
# 2023-09  0.000752  0.000095  0.000019  0.000003   NaN  0.000006  0.000019
# 2023-10  0.000024  0.000110  0.000021  0.000006   NaN  0.000006  0.000046
# 2023-11  0.000029  0.000116  0.000022  0.000006   NaN  0.000006  0.000061
# 2023-12  0.000675  0.000230  0.000022       NaN   NaN  0.000006  0.000493
#
#          AAI      AAIC       AAL  ...      ZVIA  ZVO  ZVXI  ZWRK       ZWS  \
# date                              ...
# 1925-12  NaN       NaN       NaN  ...       NaN  NaN   NaN   NaN       NaN
# 1926-01  NaN       NaN       NaN  ...       NaN  NaN   NaN   NaN       NaN
# 1926-02  NaN       NaN       NaN  ...       NaN  NaN   NaN   NaN       NaN
# 1926-03  NaN       NaN       NaN  ...       NaN  NaN   NaN   NaN       NaN
# 1926-04  NaN       NaN       NaN  ...       NaN  NaN   NaN   NaN       NaN
# ...      ...       ...       ...  ...       ...  ...   ...   ...       ...
# 2023-08  NaN  0.000033  0.000031  ...  0.000042  NaN   NaN   NaN  0.000075
# 2023-09  NaN  0.000029  0.000027  ...  0.000056  NaN   NaN   NaN  0.000071
# 2023-10  NaN  0.000006  0.000024  ...  0.000001  NaN   NaN   NaN  0.000060
# 2023-11  NaN  0.000006  0.000026  ...  0.000001  NaN   NaN   NaN  0.000120
# 2023-12  NaN  0.000005  0.000029  ...  0.000001  NaN   NaN   NaN  0.000102
#
#          ZY      ZYME      ZYNE      ZYXI  ZZ
# date
# 1925-12 NaN       NaN       NaN       NaN NaN
# 1926-01 NaN       NaN       NaN       NaN NaN
# 1926-02 NaN       NaN       NaN       NaN NaN
# 1926-03 NaN       NaN       NaN       NaN NaN
# 1926-04 NaN       NaN       NaN       NaN NaN
# ...      ..       ...       ...       ...  ..
# 2023-08 NaN  0.000015  0.000074  0.000115 NaN
# 2023-09 NaN  0.000034  0.000007  0.000066 NaN
# 2023-10 NaN  0.000106  0.000013  0.000038 NaN
# 2023-11 NaN  0.000044       NaN  0.000039 NaN
# 2023-12 NaN  0.000260       NaN  0.000076 NaN
#
# [1177 rows x 7083 columns]
